# %% [markdown]
# # Credit Default Prediction — Project Progress Tracker
#
# ---
#
# ## Notebook 01 — Raw Data Exploration
#
# - [x] Section 1 — Dataset loading and structure inspection
# - [x] Section 2 — Target variable analysis
#   - [x] Loan status classification (resolved vs unresolved)
#   - [x] df_resolved created (1,348,099 rows)
#   - [x] default_flag created (1 = Default, 0 = Non-Default)
#   - [x] Class balance confirmed (19.98% default rate)
# - [x] Section 3 — Missing value analysis
#   - [x] missing_summary() function
#   - [x] Tier classification (58 drop / 26 impute / 29 complete)
#   - [x] Leakage columns identified (36 columns)
# - [x] Section 4 — Numeric feature distributions
#   - [x] Side-by-side distributions (default vs non-default)
#   - [x] Median separation table
# - [x] Section 5 — Categorical feature analysis
#   - [x] default_rate_by_category() function
#   - [x] Grade and sub-grade
#   - [x] Term, emp_length, home_ownership, verification_status, purpose
#   - [x] addr_state (top 10)
#   - [x] Borderline columns (all confirmed drop)
#   - [x] Summary table (min/max default rate by feature)
# - [x] Section 6 — Temporal analysis
#   - [x] issue_d parsed to issue_year
#   - [x] Loan volume by year
#   - [x] Default rate by year
#   - [x] Temporal train/test split justified (2007–2015 / 2016–2018)
# - [x] Section 7 — Feature correlation overview
#   - [x] Correlation with default_flag (leakage excluded)
#   - [x] Leakage demonstration (before vs after removal)
#   - [x] Multicollinearity heatmap
#   - [x] Redundant pairs flagged (loan_amnt/funded_amnt, open_acc/total_acc)
# - [x] Section 8 — Cleaning checklist for Notebook 02
# - [ ] Save df_resolved to parquet (end of Notebook 01)
#
# ---
#
# ## Notebook 02 — Data Cleaning
#
# - [ ] Section 1 — Load df_resolved, confirm baseline shape
# - [ ] Section 2 — Drop leakage columns (36)
# - [ ] Section 3 — Drop high-missing and administrative columns
# - [ ] Section 4 — Drop zero-signal columns
# - [ ] Section 5 — Impute missing values
#   - [ ] mths_since_last_delinq → ever_delinq flag + sentinel impute
#   - [ ] mths_since_recent_inq → sentinel impute (999)
#   - [ ] emp_length → "Unknown" category
#   - [ ] revol_util → median impute
#   - [ ] Remaining Tier 3 → median / mode impute
# - [ ] Section 6 — Transformations
#   - [ ] log_annual_inc
#   - [ ] Review loan_amnt and revol_bal for log transform
# - [ ] Section 7 — Temporal train/test split
# - [ ] Section 8 — Save processed datasets to data/processed/
# - [ ] Section 9 — Before vs after cleaning summary
#
# ---
#
# ## Notebook 03 — EDA on Clean Data + Reject Inference
#
# - [ ] EDA on cleaned df_train
# - [ ] Reject inference analysis using rejected_2007_to_2018Q4.csv
#   - [ ] Compare accepted vs rejected borrower profiles
#   - [ ] Document selection bias implications
#
# ---
#
# ## Notebook 04 — Feature Engineering and WoE Encoding
#
# - [ ] WoE + IV calculation for all features
# - [ ] Drop features with IV < 0.02 (no predictive power)
# - [ ] Bin numeric features
# - [ ] Encode categorical features with WoE
# - [ ] Final feature selection
#
# ---
#
# ## Notebook 05 — Logistic Regression PD Model
#
# - [ ] Baseline logistic regression
# - [ ] Walk-forward cross-validation
# - [ ] Evaluation: AUROC, Gini, KS statistic
# - [ ] Calibration assessment
# - [ ] Scorecard construction
# - [ ] Feature coefficient analysis
#
# ---
#
# ## Notebook 06 — Gradient Boosting Challenger + ECL Analysis
#
# - [ ] XGBoost model
# - [ ] LightGBM model
# - [ ] Walk-forward CV for both
# - [ ] Head-to-head comparison vs logistic regression
# - [ ] ECL = PD × LGD × EAD
#   - [ ] Empirical LGD from observed recoveries
#   - [ ] EAD from funded_amnt
#   - [ ] Portfolio-level ECL calculation
#
# ---
#
# ## GitHub Repository
#
# - [ ] README.md — methodology, results table, setup instructions
# - [ ] requirements.txt or environment.yml
# - [ ] notebooks/ — all 6 notebooks clean and runnable
# - [ ] outputs/ — all charts saved
# - [ ] data/raw/ — raw files (gitignored if large)
# - [ ] data/processed/ — cleaned parquet files (gitignored)
#
# ---
#
# ## CV and LinkedIn
#
# - [ ] Update CV with project metrics once Notebook 06 complete
# - [ ] Add project to LinkedIn Projects section
# - [ ] Write companion blog post explaining methodology
#
# ---
#
# ## Current Status
# **In progress:** End of Notebook 01 — saving df_resolved to parquet
# **Next:** Notebook 02 — Data Cleaning
